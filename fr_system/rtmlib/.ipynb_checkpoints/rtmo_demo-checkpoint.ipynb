# %%
import time

import cv2

from rtmlib import Body, draw_skeleton, RTMPose, RTMO, Wholebody

import matplotlib.pyplot as plt

# import numpy as np

device = 'cpu'
backend = 'onnxruntime'  # opencv, onnxruntime, openvino

cap = cv2.VideoCapture(0)


openpose_skeleton = False  # True for openpose-style, False for mmpose-style
# Out:
# [ WARN:0@638.813] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@638.813] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range

# %%
whole = Wholebody(pose='/lustre/fswork/projects/rech/irm/uzq68by/code/models/rtmw-dw-x-l-384x288/end2end.onnx',  # download link or local path
                    det_input_size = (640,640),
                    det = '/lustre/fswork/projects/rech/irm/uzq68by/code/models/yolo_m_8/end2end.onnx',
                     backend=backend, device=device)
# Out:
# 2025-10-30 19:27:04.806853379 [E:onnxruntime:Default, env.cc:226 ThreadMain] pthread_setaffinity_np failed for thread: 776427, index: 9, mask: {10, 50, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-10-30 19:27:04.806903101 [E:onnxruntime:Default, env.cc:226 ThreadMain] pthread_setaffinity_np failed for thread: 776429, index: 11, mask: {12, 52, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# 2025-10-30 19:27:04.806896358 [E:onnxruntime:Default, env.cc:226 ThreadMain] pthread_setaffinity_np failed for thread: 776428, index: 10, mask: {11, 51, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# ...

# %%
image = cv2.imread("demo.jpg")
image = cv2.imread("/lustre/fswork/projects/rech/irm/uzq68by/data/CelebAMask-HQ/CelebA-HQ-img/0.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
image
# Out:
# array([[[126,  91,  72],
#         [128,  93,  74],
#         [130,  94,  78],
#         ...,
#         [176, 167, 150],
#         [176, 167, 150],
#         [177, 168, 151]],
#
#        [[129,  92,  73],
#         [132,  95,  76],
#         [134,  97,  79],
#         ...,
#         [179, 170, 153],
#         [180, 171, 154],
#         [180, 171, 154]],
#
#        [[134,  96,  75],
#         [137,  99,  78],
#         [143, 102,  84],
#         ...,
#         [185, 176, 159],
#         [185, 176, 159],
#         [185, 176, 159]],
#
#        ...,
#
#        [[116, 126,  76],
#         [116, 126,  76],
#         [116, 126,  76],
#         ...,
#         [113, 121,  80],
#         [106, 114,  73],
#         [105, 113,  72]],
#
#        [[114, 126,  76],
#         [114, 127,  74],
#         [114, 126,  76],
#         ...,
#         [107, 118,  75],
#         [111, 119,  78],
#         [121, 132,  89]],
#
#        [[ 98, 115,  61],
#         [ 92, 109,  54],
#         [ 98, 112,  59],
# ...

# %%
image_pre, ratio = pose_model.pose_model.preprocess(image)
image_pre.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 image_pre, ratio = pose_model.pose_model.preprocess(image)
#       2 image_pre.shape
#
# TypeError: RTMPose.preprocess() missing 1 required positional argument: 'bbox'

# %%
plt.imshow(image_pre)

# %%
bboxes = whole.det_model(image)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgument                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 bboxes = whole.det_model(image)
#
# File /lustre/fswork/projects/rech/irm/uzq68by/code/anonymization/models/rtmlib/rtmlib/tools/object_detection/yolox.py:29, in YOLOX.__call__(self, image)
#      27 def __call__(self, image: np.ndarray):
#      28     image, ratio = self.preprocess(image)
# ---> 29     outputs = self.inference(image)[0]
#      30     results = self.postprocess(outputs, ratio)
#      31     return results
#
# File /lustre/fswork/projects/rech/irm/uzq68by/code/anonymization/models/rtmlib/rtmlib/tools/base.py:127, in BaseTool.inference(self, img)
#     124     for out in self.session.get_outputs():
#     125         sess_output.append(out.name)
# --> 127     outputs = self.session.run(sess_output, sess_input)
#     128 elif self.backend == 'openvino':
# ...

# %%
keypoints.shape
# Out:
# (1, 133, 2)

# %%
keypoints, scores = whole(image)

# %%
image = draw_skeleton(image,
                            keypoints,
                            scores,
                            openpose_skeleton=openpose_skeleton,
                            kpt_thr=0.3,
                            line_width=2)

# %%
plt.imshow(image)

# %%
openpose_skeleton = False  # True for openpose-style, False for mmpose-style

body = Body(
    pose='rtmo',
    to_openpose=openpose_skeleton,
    mode='balanced',  # balanced, performance, lightweight
    backend=backend,
    device=device)

frame_idx = 0

while cap.isOpened():
    success, frame = cap.read()
    frame_idx += 1

    if not success:
        break
    s = time.time()
    keypoints, scores = body(frame)
    det_time = time.time() - s
    print('det: ', det_time)

    img_show = frame.copy()

    # if you want to use black background instead of original image,
    # img_show = np.zeros(img_show.shape, dtype=np.uint8)

    img_show = draw_skeleton(img_show,
                             keypoints,
                             scores,
                             openpose_skeleton=openpose_skeleton,
                             kpt_thr=0.3,
                             line_width=2)

    img_show = cv2.resize(img_show, (960, 640))
    cv2.imshow('img', img_show)
    cv2.waitKey(10)
# Out:
# Downloading: "https://download.openmmlab.com/mmpose/v1/projects/rtmo/onnx_sdk/rtmo-m_16xb16-600e_body7-640x640-39e78cc4_20231211.zip" to /linkhome/rech/gengcb01/uzq68by/.cache/rtmlib/hub/checkpoints/rtmo-m_16xb16-600e_body7-640x640-39e78cc4_20231211.zip
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 openpose_skeleton = False  # True for openpose-style, False for mmpose-style
# ----> 3 body = Body(
#       4     pose='rtmo',
#       5     to_openpose=openpose_skeleton,
#       6     mode='balanced',  # balanced, performance, lightweight
#       7     backend=backend,
#       8     device=device)
#      10 frame_idx = 0
#      12 while cap.isOpened():
#
# ...
